# %%
# >>> INTRODUCTION <<
##DOCSTRING

#145 words
"""Welcome to the text game, the first in a series of games based on the film 
genius director J.Nolan's Interstellar (2014). During the game, you will go through 
the first part of the film - until the moment you leave Earth to meet fantastic adventures.

You can choose two versions of the game: a short one with limited interaction (1-3 minutes) 
and a long one with augmented story reality and enhanced interaction (2-6 minutes).

During the game, you will go through three chapters:
   1. Finding a strange sequence of signs that will indicate the coordinates on the map.
   2. Driving a car along with these coordinates and get into trouble.
   3. Deciding to save humanity and fly to space.
   
I hope that the description of the game has intrigued you and that you enjoy the game!

P.S. This is my first experience in coding :) """

#Bugs Information
"""
1. The table inside with decryption information does not open well on narrow screens like a Mac.
"""

#-----------------------------------------------------------------------------

# Take an action for starting the game
input(prompt = "<Press ENTER to start the Game!> ")

#import through-stages packages
import time
from sys import exit

# UNDONE! Asking about preferred way of passing the game: Short or Full (sh/f)
time.sleep(1) #time delay during 1 second for a comfortable user experience

print("""\nYou have two options for how you can play this game...
1. You can play the full version (extended storylines and the ability to play a mini-game within 
the main storyline). The game can take from 2 to 10 minutes.
2. You can play the short version (all the main gist, with a limited number of interactive interactions). 
The game can take from 1 to 3 minutes.""")
time.sleep(3)   #time delay during 3 seconds for a comfortable user experience

#Asking a question
while True:
    version = input(prompt = "\n>> Do you choose 1. Full or 2. Short version? > ") #!!!!>>>>>UNDONE
    
    if 'sh' in version.lower():
        version = 0   #a binary unit for providing a short plot further
        print("""\nThis is a good choice for a pleasant and quick pastime!
Next time try the full version, where you can play as several characters
and find out additional plot circumstances.""")
        break
    
    elif 'f' in version.lower():
        version = 1   #a binary unit to supplement a short plot with new features
        print("""\nCongratulations on your great choice! This is an excellent opportunity
to plunge into the world of an unforgettable adventure, where you can play as several characters
and find out additional plot circumstances.""")
        break
    
    elif '2' in version:
        version = 0   #a binary unit for providing short plot further
        print("""\nThis is a good choice for a pleasant and quick pastime!
Next time try the full version, where you can play as several characters 
and find out additional plot circumstances.""")
        break
    
    elif '1' in version: 
        version = 1   #a binary unit to supplement a short plot with new features
        print("""\nCongratulations on your great choice! This is an excellent opportunity
to plunge into the world of an unforgettable adventure, where you can play as several characters
and find out additional plot circumstances.""")
        break
    
    else:
        print("Try again, please! Write the word 'full' or 'short', or the number '1' or '2'.")

#-----------------------------------------------------------------------------
def fail_exemplary_family_man(): 
      
    import time
    time.sleep(1)   #time delay during 1 second for a comfortable user experience
    
    print("\n" + "-" * 100)
    print(""">>> YOU HAVE DISCOVERED "THE EXEMPLARY FAMILY MAN" END!...""")
    print("-" * 100)
    time.sleep(3)   #time delat during 2 seconds for a comfortable user experience
    
    #Ending Context
    print("""\nYou return home to your daily life as a farmer, surrounded by your children and grandfather. 
Humanity is slowly living out its age...""")
    time.sleep(3)   #time delay during 2 seconds for a cinematic effect
    
    print("""\nChildren grow up. Teachers at the school say that Murph has excellent intellectual potential, 
she could find a solution to help humanity, but not on Earth, but you missed the opportunity...""")
    time.sleep(3)   #time delay during 2 seconds for a cinematic effect
    
    print("""\nOver time, Tom finishes school, becomes a farmer, and finds a girlfriend, Lois, with whom they 
have two boys. However, due to constant sandstorms and hunger, the first child dies. Over time, 
Lois also fails due to pneumonia caused by dust.""")
    time.sleep(3)   #time delay during 2 seconds for a cinematic effect
    
    print("""\nThirty years later, the latest agricultural crop, corn, that can survive on farm fields is dying... 
After several decades, the last food supplies of mankind run out, and people finally die.""") 
    time.sleep(3)
    
    print("""\n>>> THE END!""")
    
    # Restarting option
    while True:
        restart = input(prompt = "\n>> Do you want to play the game again? > ")  #asking for Restart or not

        # If user made a positive choice, then asking about stage of starting
        if 'ye' in restart.lower() or 'sur' in restart.lower() or 'cour' in restart.lower() or 'start' in restart.lower() or 'again' in restart.lower():
            while True:

                try:
                    restart_st = input(prompt = """\n>> Where would you like to start playing?
  1. From the Beginning of the game
  2. From the Chapter "On the Road!" (from the moment you are going to go on the road)
  3. From the Chapter "In the Building" (from the moment you wake up in a mysterious building) > """)

                    # Start from the beginning (first chapter)
                    if '1' in restart_st or 'begin' in restart_st.lower() or 'start' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_1()

                    # Start from the second chapter
                    elif '2' in restart_st or 'road' in restart_st.lower() or 'go' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_2()

                    # Start from the third chapter
                    elif '3' in restart_st or 'build' in restart_st.lower() or 'wake' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_3()

                    # Exit
                    elif 'exit' in restart_st.lower():
                        time.sleep(0.5)
                        print("""> Thanks for playing! I hope you come back here again. Bye :) """)
                        break

                    else: #for incorrect entry
                        print("""> Try again! Write """ + '\033[1m' + "'1'" + '\033[0m' + 
""" if you want to start the game over; """ 
+ '\033[1m' + "'2'" + '\033[0m' + """ if you're going to start with the chapter "On the road", 
or """ + '\033[1m' + "'3'" + '\033[0m' + """ if you want to start with the chapter "In the building"."""+
""" If you're going to exit the game, write """ + '\033[1m' + "'Exit'" + '\033[0m' + """.""")

                except:   #for checking bugs
                    print("""Invalid entry. Something went wrong.""")
            break
    
        # Exit
        elif 'no' in restart.lower() or 'exit' in restart.lower() or 'close' in restart.lower():
            time.sleep(0.5)
            print("""> Thanks for playing! I hope you come back here again. Bye :) """)
            break
            exit(0)

        else:   #for incorrect entry
            print("""> Try again! Write """ + '\033[1m' + 'Yes' + '\033[0m' + """ if you want to replay the game, or """ 
+ '\033[1m' + 'No' + '\033[0m' + """ if you want to finish playing.""")
    
#-----------------------------------------------------------------------------    
def vic_astronaut():

    import time
    time.sleep(1)

    print("\n" + "-" * 100)
    print(""">>> CONGRATULATIONS!!! YOU HAVE DISCOVERED "THE SPACE TRIP" END!...""")
    print("-" * 100)
    time.sleep(3)   #time delat during 2 seconds for a comfortable user experience
    
    #Ending Context
    print("""\nEngine activation.\n""")
    time.sleep(1.5)   #time delay during 1.5 seconds for a cinematic effect
    
    #Counting down and Start!
    space_cd = ['5', '.', '.', '.', '4', '.', '.', '.', '3', '.', '.', '.', '2', '.', '.', '.', 
                  '1', '.', '.', '.', 'Start!']
    for countdown in space_cd:
        time.sleep(0.25)
        print(countdown, end = '', flush = True)
    
    time.sleep(0.5)   #time delay during 0.5 seconds for a cinematic effect
    
    print("""\n\nSpace Robot Assistant Sounds: “The sound barrier has been broken. Everything is okay? 
My robot colony needs healthy slaves.” (joke)""")
    time.sleep(3)
    
    print("""\n>>> THE END!""")
    
    # Restarting option
    while True:
        restart = input(prompt = "\n>> Do you want to play the game again? > ")  #asking for Restart or not

        # If user made a positive choice, then asking about stage of starting
        if 'ye' in restart.lower() or 'sur' in restart.lower() or 'cour' in restart.lower() or 'start' in restart.lower() or 'again' in restart.lower():
            while True:

                try:
                    restart_st = input(prompt = """\n>> Where would you like to start playing?
  1. From the Beginning of the game
  2. From the Chapter "On the Road!" (from the moment you are going to go on the road)
  3. From the Chapter "In the Building" (from the moment you wake up in a mysterious building) > """)

                    # Start from the beginning (first chapter)
                    if '1' in restart_st or 'begin' in restart_st.lower() or 'start' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_1()

                    # Start from the second chapter
                    elif '2' in restart_st or 'road' in restart_st.lower() or 'go' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_2()

                    # Start from the third chapter
                    elif '3' in restart_st or 'build' in restart_st.lower() or 'wake' in restart_st.lower():
                        time.sleep(1)
                        print("""\n> In a couple of seconds, the desired scene will begin...""")
                        time.sleep(2)
                        Stage_3()

                    # Exit
                    elif 'exit' in restart_st.lower():
                        time.sleep(0.5)
                        print("""> Thanks for playing! I hope you come back here again. Bye :) """)
                        break

                    else: #for incorrect entry
                        print("""> Try again! Write """ + '\033[1m' + "'1'" + '\033[0m' + 
""" if you want to start the game over; """ 
+ '\033[1m' + "'2'" + '\033[0m' + """ if you're going to start with the chapter "On the road", 
or """ + '\033[1m' + "'3'" + '\033[0m' + """ if you want to start with the chapter "In the building"."""+
""" If you're going to exit the game, write """ + '\033[1m' + "'Exit'" + '\033[0m' + """.""")

                except:   #for checking bugs
                    print("""Invalid entry. Something went wrong.""")
            break
    
        # Exit
        elif 'no' in restart.lower() or 'exit' in restart.lower() or 'close' in restart.lower():
            time.sleep(0.5)
            print("""> Thanks for playing! I hope you come back here again. Bye :) """)
            break
            exit(0)

        else:   #for incorrect entry
            print("""> Try again! Write """ + '\033[1m' + 'Yes' + '\033[0m' + """ if you want to replay the game, or """ 
+ '\033[1m' + 'No' + '\033[0m' + """ if you want to finish playing.""")

#-----------------------------------------------------------------------------
def Stage_1():

    import time  #for preventing bugs
    
    # >>> PLOT INTRODUCTION <<<
    # Take an action for starting the game
    input(prompt = "<Press ENTER to start your unforgettable journey!> ")

    # Introduction yourself as a main character
    time.sleep(1)
    print("\n" + "-" * 100)
    print("""You are a former NASA engineer and pilot, """ + '\033[1m' + 'Joseph Cooper' + '\033[0m' + 
    """, now a widowed farmer, \nraising two children - a daughter, Murph, a girl with high intelligence, and a son, Tom. 
The latter is not so intelligent and wants to become a true farmer.""")

    # Time delay during 3 seconds for a cinematic effect
    import time
    time.sleep(3) 

    # More context about humanity, with options of the Short and Full description (sh/f)
    if version == 0:   #for a short version
        print("""\nHumanity is on the brink of extinction...""")

    elif version == 1:   #for a full version
        print("""\nHumanity is on the brink of extinction... 
The potato disappeared a few years ago, the wheat died last year, the okra all died out this year. 
Farmers grow only corn, but every year it becomes less and less. Dust reigns everywhere, 
which clogs into all the cracks in houses and gets into the lungs. People move around in masks.""")

    else:   #for checking bugs
        print("""Invalid entry! Something went wrong.""")

    #Time delay during 2/5 seconds for a comfortable user experience
    if version == 0:
        time.sleep(2)   #2 seconds for a short version of a plot
    elif version == 1:
        time.sleep(5)   #5 seconds for a full version of a plot
    else:               #for checking bugs
        print("""Invalid entry! Something went wrong.""")


    # >>> FIRST ACTION SCENE <<<

    # First Action Scene: context
    print("""\nTypical day. You are going to a baseball game with your children. 
As you leave Murph's room with her, you notice how the model of the spaceship and then 
the books on the shelf in the bookcase fall.""")

    # First Action Scene: asking about an action, which you should make
    ## Asking a Main Question for an action with a time delay between context and task
    time.sleep(4)

    while True:
        fir_act = input(prompt = """>> What will you do?
        1. You will not attach any importance to it.
        2. You ask Murph if this has happened before. > """)

        # Several text options for choosing 1st answer by user (Main Question)
        if 'no' in fir_act.lower():
            print("""\nHowever, several more books fall after a while, and you notice that Murph 
takes a notebook and begins to write something down. """)

            # Asking Sub-Question for action
            while True:
                fir_act_fir = input(prompt = ">> Will you ask her this time? > ")

                # Plot direction in case of 1st answer by user (Sub-Question)
                if 'ye' in fir_act_fir.lower() or 'sur' in fir_act_fir.lower() or 'cour' in fir_act_fir.lower():
                    print("""\nMurph thinks the Ghost is trying to tell her something in Morse code. 
However, you do not believe this and say that the bookshelves hardly talk to her. 
You are going down the stairs into the street.""")
                    break

                # Plot direction in case of 2nd answer by user (Sub-Question)
                elif 'no' in fir_act_fir.lower():
                    print("""\nYou are going down the stairs into the street.""")
                    break

                else:   #user's helper with an incorrect input
                    print("Try again, please! Write 'Yes' or 'No'.")
            break

        # Numerical option for choosing 1st answer by user (Main Question)
        elif '1' in fir_act:
            print("""\nHowever, several more books fall after a while, and you notice that Murph 
takes a notebook and begins to write something down. """)

            # Asking Sub-Question for an action
            while True:
                fir_act_fir = input(prompt = ">> Will you ask her this time? > ")

                # Plot direction in case of 1st answer by user (Sub-Question)
                if 'ye' in fir_act_fir.lower() or 'sur' in fir_act_fir.lower() or 'cour' in fir_act_fir.lower():
                    print("""\nMurph thinks the Ghost is trying to tell her something in Morse code. 
However, you do not believe this and say that the bookshelves hardly talk to her. 
You are going down the stairs into the street.""")
                    break

                # Plot direction in case of 2nd answer by user (Sub-Question)
                elif 'no' in fir_act_fir.lower():
                    print("""\nYou are going down the stairs into the street.""")
                    break

                else:   #user's helper with an incorrect input
                    print("Try again, please! Write 'Yes' or 'No'.")
            break

        # Several text options for choosing 2nd answer by user (Main Question)
        elif 'ask' in fir_act.lower():
            print("""\nMurph thinks the Ghost is trying to tell her something in Morse code. 
However, you do not believe this and say that the bookshelves hardly talk to her. 
You are going down the stairs into the street.""")
            break

        # Numerical option for choosing 2nd answer by user (Main Question)
        elif '2' in fir_act: 
            print("""\nMurph thinks the Ghost is trying to tell her something in Morse code. 
However, you do not believe this and say that the bookshelves hardly talk to her. 
You are going down the stairs into the street.""")
            break

        else:   #user's helper with an incorrect input
            print("Try again, please! Write the number '1' or '2'.")

    # Time delay during 3 seconds for a comfortable user experience
    time.sleep(3)

    # >>> CONTEXT <<<
    if version == 0:   #for a short version
        print("""\nWhen Murph comes down you get in your car and drive to a baseball game with your family and your 
wife's father, who lives with you on the farm. However, after a while, a powerful sandstorm begins, 
and you decide to return without tasting popcorn and hot dogs :(""")

    elif version == 1:   #for a full version
        print("""\nWhen you go outside, you notice that all the harvesters you have repaired for yourself 
and other farmers are lined up around your house! Probably the navigation systems broke down 
due to a magnetic anomaly at home, you think. You decide to deal with this problem later 
and drive to a baseball game with your family and your wife's father, who lives with you on the farm. 
After a while, a powerful sandstorm begins, and you decide to return without tasting popcorn and hot dogs :(""")

    else:   #for checking bugs
        print("Invalid entry! Something went wrong.")

    time.sleep(4) #time delay during 4 seconds for comfortable user experience

    # Mini educational game (Optional)
    # Context
    print("""\nUnfortunately, when you returned home, you see dust flying in the house and learn that Murph did not close 
the window in her room. You run to her room and close the window. The settling dust forms a strange 
pattern of dots and stripes on the floor where books have fallen... You understand that this is not Morse code 
but a """ + '\033[1m' + 'binary code' + '\033[m' + """ that points to something.""")
    time.sleep(3) #time delay during 3 seconds for a comfortable user experience 

    # Asking a question with a choice: whether to play the game or not
    if version == 1:   #only available in a full version of a plot
        while True:
            mini_g_opt = input(prompt = """\n>> Do you want to decrypt the code personally or do it automatically? > """)

            try:
                if 'person' in mini_g_opt:
                    mini_g_opt_ch = 1
                    print("""> Great choice! Welcome to the world of cryptography ;)\n 
After a few seconds, you see ... how lines and dots in the sand turn to 0 and 1 on paper""")
                    break

                elif 'self' in mini_g_opt:
                    mini_g_opt_ch = 1
                    print("""> Great choice! Welcome to the world of cryptography ;)\n 
After a few seconds, you see ... how lines and dots in the sand turn to 0 and 1 on paper""")
                    break

                elif 'auto' in mini_g_opt:
                    mini_g_opt_ch = 0
                    print("""> Human technology has advanced and allows you to quickly decipher the code. """)
                    break

                elif 'comp' in mini_g_opt:
                    mini_g_opt_ch = 0
                    print("""> \nHuman technology has advanced and allows you to quickly decipher the code. """)
                    break

                else:
                    print("> Try again! Enter the word 'personally' or 'automatically'. ")
                    time.sleep(1.5)   #time delay during 1.5 seconds for a comfortable user experience

            except:
                print("""Invalid entry! Something went wrong.""")

    elif version == 0:   #no option of playing in that game in a short version 
        mini_g_opt_ch = 0

    else:   #for checking bugs
        print("""Something went wrong.""")

    # The game
    time.sleep(2) #time delay during 2 seconds for a comfortable user experience
    if mini_g_opt_ch == 1: #for decryptyon personally

        #29.562222.-95.090833 (NASA coordinates in Houston) in binary code
        print("""\n00110010  00111001  00101110  00110101  00110110  00110010  00110010  00110010  00110010  00101110 
00101101  00111001  00110101  00101110  00110000  00111001  00110000  00111000  00110011  00110011\n""")

        time.sleep(2)
        print(""">> You need to translate these characters that appeared in the sand, and write them!
You can use the """ + '\033[1m' + 'help' + '\033[0m' + """ for an additional decryption information. 
Have an excellent game!""")
        time.sleep(1.5)

        # To prevent a situation when the user cannot solve the problem and go further
        chances = 3
        stop_0 = 0   #preventing bug with the unstoppable loop

        while chances >= 1 and stop_0 == 0:
            answ = input(prompt = "\n>> Enter the resulting numbers and symbols > ")

            try:
                # Asking a system for the help
                if 'help' in answ.lower():
                    print("""\n> Use this table to convert binary codes to numbers:\n""")

                    import pandas as pd   #importing the package

                    # Content of Decryption Information
                    table = pd.DataFrame({'Number or Sign: ': ['Binary code: '],
                                          '0': ['00110000'],
                                          '1': ['00110001'],
                                          '2': ['00110010'],
                                          '3': ['00110011'],
                                          '4': ['00110100'],
                                          '5': ['00110101'],
                                          '6': ['00110110'],
                                          '7': ['00110111'],
                                          '8': ['00111000'],
                                          '9': ['00111001'],
                                          '-': ['00101101'],
                                          '.': ['00101110']})

                    print(table.to_string(index = False))   #printing the tablewithout an index column

                # Right answer
                elif '29.562222' in answ and '-95.090833' in answ:
                    print("""\nMurph seems to have deciphered everything correctly.""")
                    break

                # If latitude is right, but longitude is not
                elif '29.562222' in answ: 
                    print("""\n> You spelled latitude correctly. Consider longitude. Keep up the excellent work; 
there is minimal left!""")
                    chances -= 1

                # If longitude is right, but latitude is not
                elif '95.090833' in answ:
                    print("""\n> You spelled longitude correctly. Consider latitude. Keep up the excellent work;
there is minimal left!""")
                    chances -= 1

                # Easter egg...
                elif 'nasa' in answ.lower():
                    print("""
                                    888 888                   888    
                                    888 888                   888    
                                    888 888                   888    
 .d88b.  888  888  .d8888b  .d88b.  888 888  .d88b.  88888b.  888888 
d8P  Y8b `Y8bd8P' d88P"    d8P  Y8b 888 888 d8P  Y8b 888 "88b 888    
88888888   X88K   888      88888888 888 888 88888888 888  888 888    
Y8b.     .d8""8b. Y88b.    Y8b.     888 888 Y8b.     888  888 Y88b.  
"Y8888  888   888  "Y8888P  "Y8888  888 888  "Y8888  888  888 "Y888

And you obviously already know something ... 
Maybe I should let you go straight into space because you seem to really want it!""")

                elif chances == 1:
                    print("""\nThe stripes and dots in the sand that transform into binary code (0 and 1) begin to change 
rapidly when you plug into the data decryption engine leftover from service in Nasa...""")
                    time.sleep(2) #time delay during 2 seconds for a cinematic effect

                    # For stopping the loop
                    stop_0 = 1

                    # Cinematic Scene of Decryption of the binary digits into hexadecimal digits
                    indexs = 0

                    # Original list with binary digits
                    binary_lst = ['00110010', '00111001', '00101110', '00110101', '00110110', 
                            '00110010', '00110010', '00110010', '00110010', '00101110', 
                            '00101101', '00111001', '00110101', '00101110', '00110000',
                            '00111001', '00110000', '00111000', '00110011', '00110011']

                    # List with hexadecmal digits for replacing
                    number_lst = ['2','9', '.', '5', '6', '2', '2', '2', '2', '.', '-', 
                                  '9', '5', '.', '0', '9', '0', '8', '3', '3']

                    # Creating a system of replacing digits in a list one-by-one with a time delay between steps
                    while indexs < len(binary_lst) + 1:
                        print("".join(binary_lst), end = '       \r')  #start in the same output line 
                        time.sleep(0.25)                      #time delay for 0.25 second between replacing steps

                        if indexs != len(binary_lst):         #mechanism of replacing digits in a list by an increased index
                            binary_lst[indexs] = binary_lst[indexs].replace(binary_lst[indexs], number_lst[indexs])
                            indexs = indexs + 1

                        elif indexs == len(binary_lst):       #stop the loop after reaching the len(lst)
                            break

                        else:                                 #for checking bugs
                            print("Something went wrong.")

                # If user puts an incorrect value in the input line
                else:
                    chances -= 1
                    if chances != 0:
                        print("""\n> Try to translate the binary from left to right and top to bottom, with no spaces. 
If you have difficulty translating words yourself, write """ + '\033[1m' + 'help' + '\033[0m' + f""" in the input line. 
Do not worry; after remaining {chances} attempt(s), I will show the correct answer and continue the story.""") 
                    else:
                        continue

            except:
                print("""Invalid entry. Something went wrong.""")


    if mini_g_opt_ch == 0: #for decryptyon automatically and SHORT version of the plot
        print("""\nThe stripes and dots in the sand that transform into binary code (0 and 1) begin to change rapidly 
when you plug into the data decryption engine leftover from service in Nasa...""")
        time.sleep(2) #time delay during 2 seconds for a cinematic effect

        # Cinematic Scene of Decryption of the binary digits into hexadecimal digits
        indexs = 0

        # Original list with binary digits
        binary_lst = ['00110010', '00111001', '00101110', '00110101', '00110110', 
                '00110010', '00110010', '00110010', '00110010', '00101110', 
                '00101101', '00111001', '00110101', '00101110', '00110000',
                '00111001', '00110000', '00111000', '00110011', '00110011']

        # List with hexadecmal digits for replacing
        number_lst = ['2','9', '.', '5', '6', '2', '2', '2', '2', '.', '-', '9', '5', '.', '0', '9', '0', '8', '3', '3']

        # Creating a system of replacing digits in a list one-by-one with a time delay between steps
        while indexs < len(binary_lst) + 1:
            print("".join(binary_lst), end = '       \r')  #start in the same output line 
            time.sleep(0.25)                      #time delay for 0.25 second between replacing steps

            if indexs != len(binary_lst):         #mechanism of replacing digits in a list by an increasing index
                binary_lst[indexs] = binary_lst[indexs].replace(binary_lst[indexs], number_lst[indexs])
                indexs = indexs + 1

            elif indexs == len(binary_lst):       #stop the loop after reaching the len(lst)
                break

            else:                                 #for checking bugs
                print("Something went wrong.")

    # Context
    print("""\n\nYou understand that these are some coordinates. You unfold your physical map of the area 
and find the way to this place...""")
    time.sleep(2)
    print("""\n>>> Continued in the next chapter...""")
    time.sleep(3) #time delay for 2 seconds for comfortable user experience 
    
    Stage_2()

#-----------------------------------------------------------------------------
def idea_fence():

    import time   #for preventing bugs
        
    print("""\nYou get the idea of trying to break a metal fence by slowly ramming it with your car. 
It may not make much noise, but you are also not sure if the wall will break.""")

    stop_1 = 0   #for preventing bugs and stop the loop

    while stop_1 == 0 :
        time.sleep(2)   #time delay for 2 seconds for a comfortable user experience
        ram_ch = input(prompt = """\n>> Do you want to try ramming the fence? > """)

        try:
            # If the user put a positive answer
            if 'ye' in ram_ch.lower() or 'sur' in ram_ch.lower() or 'cour' in ram_ch.lower():
                time.sleep(0.5)   #time delay for 0.5 seconds for a cinematic effect and comfortable user experience
                print("""\nWhen you try to do this, strangers behind the fence blind you and your daughter 
and then put you to sleep...""")
                print("""\n>>> Continued in the next chapter...""")
                time.sleep(3) #time delay for 2 seconds for comfortable user experience
                Stage_3()
                break

            # If the user put a negative answer
            elif 'no' in ram_ch.lower():
                print("""You no longer have any other options on how to break the fence.""")

                while stop_1 == 0:
                    time.sleep(1.5)   #time delay for 1.5 seconds for a comfortable user experience
                    ram_ch_1 = input(prompt = """\n>> Do you want to stop trying and go home? 
Please note that you will no longer be able to come here. > """)

                    try:
                        # The user wants to stop trying and go home. Fail...
                        if 'ye' in ram_ch_1.lower() or 'sur' in ram_ch_1.lower() or 'cour' in ram_ch_1.lower():
                            fail_exemplary_family_man()
                            stop_1 += 1 #for stopping the sub loop
                            break

                        # If the user wants to try, stop sub-sub-loop and return to the question of ramming the fence
                        elif 'no' in ram_ch_1.lower():
                            break   #for stopping sub-sub-sub loop

                        # If the user puts an incorrect value in the input line
                        else:
                            print("""> Try again. Write 'yes' or 'no'.""")

                    except:   #for checking bugs
                        print("01. Invalid entry. Something went wrong.")

            else:   #if the user put an incorrect value in the input line
                print("""> Try again. Write 'yes' or 'no'.""")

        except:   #for checking bugs
            print("""0. Invalid entry. Something went wrong.""")

#-----------------------------------------------------------------------------
    
def Stage_2():

    import time   #for preventing bugs
    
    #Introduction to the chapter
    print("-" * 100)
    time.sleep(1)
    print("""The next chapter "On the Road!" begins...""")
    time.sleep(1)
    print("-" * 100)
    time.sleep(2)
    
    # Context  
    print("""\n\nIt is not very far from your farm, a 2-3 hours drive. You decide to go there because you are curious.""")
    time.sleep(2)

    print("""\nBut you need to get ready for the road and grab some things from the warehouse since you do not know 
what to expect and what may lie in wait for you.""")

    time.sleep(3)   #time delay during 2 seconds for comfortable user experience

    # Taking tools from a warehouse to a backpack with a limited number of slots
    lst_wh = ['bolt cutter', 'pillow', 'axe', 'canister of gasoline', 'rope']   #warehouse
    lst_bp = []    #backpack
    backpack = 3   #number of slots

    while backpack > 0:

        # Asking about the user's choice of taking an instrument from the warehouse list
        print(">> Choose the tool that you will take with you:")
        for tool in lst_wh:
            print('   -', tool)
        tool = input(prompt = f"Pay attention! You have {backpack} slot(s) left. > ")
        tool = tool.lower()   #making all letters in input word lowercase

        # Taking any instrument, except pillow
        if tool in lst_wh and tool != 'pillow':
            print(f"""> A rational choice! Taking the {tool} is a great idea.\n""")
            lst_bp.append(tool)   #adding the tool to the backpack
            lst_wh.remove(tool)   #removing the tool from warehouse
            backpack -= 1         #reducing the number of remaining slots
            time.sleep(1.5)       #time delay for 1.5 seconds for a comfortable user experience

        # Taking the pillow (not last affordable item)
        elif tool in lst_wh and tool == 'pillow' and backpack > 1: 
            print(f"""> Hmmm ... Okay, let's have a pillow. You may want to sleep in the car, 
but I would suggest taking something else.\n""")
            lst_bp.append(tool)   #adding the tool to the backpack
            lst_wh.remove(tool)   #removing the tool from warehouse
            backpack -= 1         #reducing the number of remaining slots
            time.sleep(1.5)       #time delay for 1.5 seconds for a comfortable user experience

        # Taking a pillow as a last affordable tool
        elif tool in lst_wh and tool == 'pillow' and backpack == 1:
            print(f"""> Hmmm ... Okay, let's have a pillow. I hope you managed to get something practical.\n""")
            lst_bp.append(tool)   #adding the tool to the backpack
            lst_wh.remove(tool)   #removing the tool from warehouse
            backpack -= 1         #reducing the number of remaining slots
            time.sleep(1.5)       #time delay for 1.5 seconds for a comfortable user experience

        # Picking up an instrument that has already been selected
        elif tool in lst_bp:
            print(f"""> You have already taken the {tool} with you. 
Think about something else, you have {backpack} slot(s) left.\n""")
            time.sleep(1.5)       #time delay for 1.5 seconds for a comfortable user experience

        # User helper with an incorrect input     
        else:   
            print("""> Try again! You need to select a tool from the list and write it, i.e., 'pillow'.\n""")
            time.sleep(1.5)

    # Printing the final message with the list of the selected instruments
    print("You have entirely packed your backpack with """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + 
""", and you are ready to go!""")


    # Action Scene
    # Context
    print("""\n... You are already calmly driving alone in the car on the way to the mysteriously found 
coordinates when an hour later, Murph jumps out of the back seat and frightens you.
However, you have already passed halfway, and this is just a trip by car, so you continue on your way.""")

    time.sleep (2) #time delay during 2 seconds for a comfortable user-experince

    # Context
    print("""\nYou drive up to the coordinates found, but there are several kilometers left to the final point 
of the trip, which is blocked by a fence with barbed wire. Your daughter tells you to try to break the metal fence.""")

    stop = 0
    stop_1 = 0
    stop_2 = 0

    # Asking for breaking the fence: yes or no, with the additional choice inside
    while stop == 0:
        time.sleep(1.5)   #time delay duting 1.5 seconds for a comfortable user experience
        r_answ = input(prompt = "\n>> Do you want to break this fence to drive on? > ")

        try:
            # If the user put a positive answer in the input line
            if 'ye' in r_answ.lower() or 'sure' in r_answ.lower() or 'cour' in r_answ.lower():
                print("""\n> It seems that you need some kind of tool for this. You look into your backpack and 
see the following tools: """ + (", ".join(lst_bp)) + """.""")

                while stop_2 == 0:
                    r_answ_1 = input(prompt = """\n>> Which tool from your backpack would you like to use for this? > """)

                    try:

                        # Making a necessary choice of a tool for breaking the fence if the bolt cutter is in the backpack
                        if 'bolt cutter' in lst_bp:

                            # If the user made a choice of a pillow, having it in the backpack
                            if 'pillow' in r_answ_1.lower():

                                if 'pillow' in lst_bp:
                                    print("""> Seriously? Why do you need a pillow? You are about to fall asleep under 
this fence or rip your pillow trying to climb over it. Not a very good idea, let's try again ...""")

                                elif 'pillow' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("1. Invalid entry. Something went wrong.")

                            # If the user made a choice of an axe, having it in the backpack
                            elif 'axe' in r_answ_1.lower():

                                if 'axe' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Let's think about another tool that might be useful to us.""")

                                elif 'axe' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("2. Invalid entry. Something went wrong.")

                            # If the user made a choice of a rope, having it in the backpack
                            elif 'rope' in r_answ_1.lower():

                                if 'rope' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Let's think about another tool that might be useful to us.""")

                                elif 'rope' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("3. Invalid entry. Something went wrong.")

                            # If the user made a choice of a cansiter of gazoline, having it in the backpack
                            elif 'canister' in r_answ_1.lower():

                                if 'canister' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Let's think about another tool that might be useful to us.""")

                                elif 'canister' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("4. Invalid entry. Something went wrong.")

                            # Right choice: if the user chose the bolt cutter
                            elif 'bolt cutter' in r_answ_1.lower():
                                print("""> Great idea! This is the most suitable tool for this.""") 
                                time.sleep(1.5) #time delay for 1.5 seconds for a cinematic effect
                                print("""\nWhen you take a bolt cutter and try to break the fence, strangers behind the 
fence blind you and your daughter and then put you to sleep...""")
                                time.sleep(3)
                                print("""\n>>> Continued in the next chapter...""")
                                time.sleep(2) #time delay for 2 seconds for comfortable user experience
                                Stage_3()
                                stop += 1   #for stopping the main loop
                                break       #for stopping the sub-loop in the main loop

                            else:
                                print("""> Try again and choose a tool from your backpack: """ 
+ '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                        # Making a choice if the user did not take a bolt cutter with him(her)self
                        elif 'bolt cutter' not in lst_bp:

                            # If the user made a choice of a pillow, having it in the backpack
                            if 'pillow' in r_answ_1.lower():

                                if 'pillow' in lst_bp:
                                    print("""> Seriously? Why do you need a pillow? You are about to fall asleep under 
this fence or rip your pillow trying to climb over it. Not a very good idea, but, unfortunately, you did not take 
a bolt cutter that could help you, and other tools will only make unnecessary noise and will not be able to break 
the fence...""")
                                    time.sleep(3)   #time delay during 3 seconds for a comfortable user experience
                                    idea_fence()
                                    stop += 1   #for stopping the main loop
                                    stop_2 += 2 #for stopping the sub loop

                                elif 'pillow' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("1. Invalid entry. Something went wrong.")

                            # If the user made a choice of an axe, having it in the backpack
                            elif 'axe' in r_answ_1.lower():

                                if 'axe' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Unfortunately, you did not take a bolt cutter that could help you, and other tools will not be able to break 
the fence.""")
                                    time.sleep(2)   #time delay during 2 seconds for a comfortable user experience
                                    idea_fence()
                                    stop += 1   #for stopping the main loop
                                    stop_2 += 2 #for stopping the sub loop

                                elif 'axe' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("2. Invalid entry. Something went wrong.")

                            # If the user made a choice of a rope, having it in the backpack
                            elif 'rope' in r_answ_1.lower():

                                if 'rope' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Unfortunately, you did not take a bolt cutter that could help you, and other tools will not be able to break 
the fence.""")
                                    time.sleep(2)   #time delay for 2 seconds for a comfortable user experience
                                    idea_fence()
                                    stop += 1   #for stopping the main loop
                                    stop_2 += 2 #for stopping the sub loop

                                elif 'rope' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("3. Invalid entry. Something went wrong.")

                            # If the user made a choice of a cansiter of gazoline, having it in the backpack
                            elif 'canister' in r_answ_1.lower():

                                if 'canister' in lst_bp:
                                    print(f"""> It seems that using the {r_answ_1.lower()} can only make unnecessary noise. 
Unfortunately, you did not take a bolt cutter that could help you, and other tools will not be able to break 
the fence.""")
                                    time.sleep(2)   #time delay for 2 seconds for a comfortable user experience
                                    idea_fence()
                                    stop += 1   #for stopping the main loop
                                    stop_2 += 2 #for stopping the sub loop

                                elif 'canister' not in lst_bp:
                                    print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                                else:
                                    print("4. Invalid entry. Something went wrong.")

                            else:
                                print("""> You did not take this item with you. Try again and choose a tool from 
your backpack: """ + '\033[1m' + (", ".join(lst_bp)) + '\033[0m' + """.""")

                        else:   #for checking bugs
                            print("Something went wrong.")

                    except:   #for checking bugs
                        print("""> Try again and choose a tool from your backpack: """ + '\033[1m' 
    + (", ".join(lst_bp)) + '\033[0m' + """.""")

            # If the user put a negative answer in the input line
            elif 'no' in r_answ.lower(): #need to add the continue
                while True:
                    time.sleep(1)   #time delay for 1 second for a comfortable user experience
                    ram_ch_1 = input(prompt = """\n>> Do you want to drive home? 
Please note that you will no longer be able to come here. > """)

                    try:
                        # The user wants to stop trying and go home. Fail...
                        if 'ye' in ram_ch_1.lower() or 'sur' in ram_ch_1.lower() or 'cour' in ram_ch_1.lower():
                            fail_exemplary_family_man()
                            stop += 1   #for stopping the main loop
                            break

                        # If the user wants to try, stop sub-sub-loop and return to the question of ramming the fence
                        elif 'no' in ram_ch_1.lower():
                            break   #return to the main loop

                        # If the user puts an incorrect value in the input line
                        else:
                            print("""> Try again. Write 'yes' or 'no'.""")

                    except:   #for checking bugs
                        print("Invalid entry. Something went wrong.")

            # If the user put an incorrect value in the input line, like 'eggplant'
            else: 
                print("> Try again. Write 'yes' or 'no'.")

        except:   #for checking bugs
            print("""2. Invalid entry. Something went wrong.""")
    
#-----------------------------------------------------------------------------
def before_leaving():

    import time   #for preventing bugs
        
    time.sleep(3)   #time delay during 3 seconds for a cinematic effect

    # Context
    print("""\n...You are driving home to say goodbye to your family. To your son Tom. To your wife's father. 
And of course, to your daughter, Murph. """)
    time.sleep(2)   #time delay during 2 seconds for a cinematic effect and comfortable user experience

    print("""\nHeartbreaking farewell scene...
You leave your watch to her and tell Murph that when you arrive home, you may be of the same age and 
by the clock you will be able to check the time with her!""")
    time.sleep(4)   #time dealy for 4 seconds for a comfortable user experience

    print("""\nMurph wants to show you something.""")
    time.sleep(1.5)

    print("""\nMurph comes up to you and says that she deciphered the time sequence of the fall 
of the books using Morse code... There is only one word written there:""")
    time.sleep(3) #time delay for 2 seconds for a cinematic effect

    # Typing effect
    word = 'S-T-A-Y'
    for letter in word:
        time.sleep(0.6)
        print(letter, end = '', flush = True)

    time.sleep(1.5)
    print("\n\nRegardless, you think your daughter made it up on purpose. You are leaving for the NASA base...\n")
    time.sleep(2)
    vic_astronaut()   # The second plot conclusion - victory!

#-----------------------------------------------------------------------------
    
def Stage_3():

    import time #for preventing bugs
    
    #Introduction to the chapter
    print("-" * 100)
    time.sleep(1)
    print("""The next chapter "In the Building" begins...""")
    time.sleep(1)
    print("-" * 100)
    time.sleep(2)
    
    # Action Scene
    # Context
    time.sleep(3)   #time delay during 3 seconds for a cinematic effect
    print("""\n\n...You wake up alone in a building. You see people approaching you. You are terrified...""") 
    time.sleep(2.5)   #time delay during 2.5 seconds for a cinematic effect

    # Context    
    print("""\nYou meet Dr. Amelia Brand and her father, Professor Brand, who was your leader at NASA. 
The place where you are is the most secret place on the planet, the station for sending NASA rockets.""")

    # Context for a long version
    if version == 1:  #addition for a long version
        time.sleep(4)   #time delat during 4 seconds for a comfortable user experience
        print("""\nThe agency closed, but after a few years, government spending on NASA resumed, but secretly. 
You understand living in a post-truth world where children are taught that humanity has never flown into space 
and that farming is the most essential concern now. """ + '\033[1m' + 
'NASA exists, and you are at the heart of it...' + '\033[0m')

    # Dialogue scene
    print("""Professor Brand (speaking suspiciously): - Hello, my dear friend. Haven't seen you for a long time. 
How did you find this place? It is the most secret object in the whole wide world.""")
    time.sleep(2)  #time delay for 2 seconds for a comfortable user experience

    # First dialoque
    while True:
        dlg_1 = input (prompt = """\n>> What do you want to say?
\n1. You (You are trying to cheat): - We were just driving with my daughter and accidentally stumbled upon a fence. 
We are already leaving...
\n2. You (You are trying to tell the truth): - I realized that the ghosts in my house were trying to tell me something... 
So I deciphered the code that brought me here.
\n3. You (You are afraid): - I will not tell you anything until you bring my daughter here immediately. 
Before I have time to look around, you will shoot us both and throw us into some cliff, which will be covered 
with dust.\n> """)

        try:
            # Making a first choice with multiple versions of choosing it
            if '1' in dlg_1 or 'cheat' in dlg_1.lower() or 'driv' in dlg_1.lower() or 'lie' in dlg_1.lower():
                time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                print("""\nProfessor Brand: - I don't think you are telling me the truth. However, it doesn't seem to matter. 
After all, humanity is dying rapidly..., and even if you want to know some secrets, soon it will not make any sense.""")
                dlg_1_next = 1
                break

             # Making a second choice with multiple versions of choosing it
            elif '2' in dlg_1 or 'truth' in dlg_1.lower() or 'deciph' in dlg_1.lower() or 'ghost' in dlg_1.lower():
                time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                print("""\nProfessor Brand: - Dear friend, it seems that I have known you for ages. You were the best pilot 
in my memory. However, it seems to me that you are crazy... Ghosts? Sand code? Perhaps you haven't been in space for 
too long... But I have a tempting offer for you!""")
                dlg_1_next = 2
                break

            # Making a third choice with multiple versions of choosing it      
            elif '3' in dlg_1 or 'afraid' in dlg_1.lower() or 'shoot' in dlg_1.lower() or 'daughter' in dlg_1.lower():
                time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                print("""\nProfessor Brand: - Dear friend, who do you think we are? We're at NASA. You've worked with us 
for so many years. Have we ever tried to kill people... Perhaps you have not been in space for too long, and the 
farming life has clouded your brain. But I have a tempting offer for you in such a case.""")
                dlg_1_next = 2
                break

            else:   #for an incorrect entry in the input line
                print("""> Perhaps you entered something wrong. Try again and enter the desired digit of the replica you 
want to say, i.e., '1', '2' or '3'.""")

        except:   #for checking bugs
            print("Invalid entry. Something went wrong.")

    # First option of a plot
    if dlg_1_next == 1:
        while True:
            try:
                # Asking a question: second dialoque
                time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                dlg_1_1 = input(prompt = """\n>> What do you want to say now?
\n1. You (puzzled and curious): - Why do you think so, professor?
\n2. You (frightened): - However, it's time for my daughter and me. Can we go? > """)

                # answer, leading to second option of a plot
                if '1' in dlg_1_1 or 'puz' in dlg_1_1.lower() or 'curi' in dlg_1_1.lower() or 'why' in dlg_1_1.lower():
                    time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                    print("""\nProfessor Brand: - Because everything dies. You know this because you are now a farmer and 
you see everything with your own eyes. But I have an offer for you to help save you, and your family, and all 
of humanity.""")
                    dlg_1_next = 2
                    break

                # answer, leading to the next dialogue, which can lead to the fail()
                elif '2' in dlg_1_1 or 'frigh' in dlg_1_1.lower() or 'time' in dlg_1_1.lower() or 'go' in dlg_1_1.lower():
                    time.sleep(0.5)   #time delay for 0.5 seconds for a comfortable user experience
                    print("""\nProfessor Brand: - Yes, we are not holding you and, of course, we are not going to kill you. 
However, you can save humanity...""")
                    while True:
                        # Asking a question, which can lead to the fail()
                        time.sleep(1) #time delay during 1 second for a comfortable user experience
                        dlg_1_1_1 = input(prompt = """\n>> Do you still want to leave? 
Please note that you will not be able to return here anymore. > """)

                        try:
                            # Asnwer, leading to the fail()
                            if 'ye' in dlg_1_1_1.lower() or 'sur' in dlg_1_1_1.lower() or 'cour' in dlg_1_1_1.lower():
                                fail_exemplary_family_man()
                                break

                            # Answer, leading to the second option of a plot
                            elif 'no' in dlg_1_1_1.lower() or 'stay' in dlg_1_1_1.lower():
                                time.sleep(0.5) #time delay during 0.5 seconds for a comfortable user experience
                                print("""It's good. I knew that you would like my offer...""")
                                dlg_1_next = 2
                                break

                            else:   #for incorrect entry in the input line
                                print("""> Perhaps you entered something wrong. Try again and write 'Yes' or 'No'.""")

                        except:   #for checking bugs
                            print("Something went wrong.")
                    break

                else:  #for incorrect entry in the input line 
                    print("""> Perhaps you entered something wrong. Try again and enter the desired digit of the replica you 
want to say, i.e., '1' or '2'.""")

            except:   #for checking bugs
                print("""Invalid entry. Something went wrong.""")

    # Second option of a plot
    if dlg_1_next == 2:
        time.sleep(2)   #time delay for 2 seconds for a cinematic effect and comfortable user experience

        #Context
        print("""\nYou will find out that Professor Brand has a plan! However, the goal is not to save the Earth 
but to leave it and save humanity. In your attempt to find out more information, Professor Brand asks you a question:""")
        time.sleep(3)  #time delay during 3 seconds for a comfortable user experience
        print("""\n"Are you ready to fly the last remaining spaceship station, Endurance, in orbit and become part of 
the team that will go into space to save humanity?" """)

        dlg_2 = 2   #for continuing the dialoque further

    # Repetitive questions of agreement or disagreement
    if dlg_2 == 2:
        while True:
            try:
                # Repetitive (containing the same question inside) question
                time.sleep(2) #time delay during 2 seconds
                dlg_3 = input(prompt = """\n>> Do you agree, refuse, or do you need more information? 
Remember, you cannot come back here again. > """)

                # Positive answer, leading to the next scene
                if 'agree' in dlg_3.lower() or 'ye' in dlg_3.lower() or 'sur' in dlg_3.lower():
                    before_leaving()  #scene at home before leaving
                    break

                # Negative answer to the question, leading to the fail()
                elif 'dis' in dlg_3.lower() or 'refuse' in dlg_3.lower() or 'no' in dlg_3.lower():
                    fail_exemplary_family_man()   #failing

                    break

                # Asking for an additional information
                elif 'info' in dlg_3.lower() or 'more' in dlg_3.lower():
                    print("""\n""" + '\033[1m' + "You find out the following information:\n" + '\033[0m' + 
"""You are the best NASA pilot in years and the only one who did a real flight, not a simulation, 
on the team of people flying into space, including Dr. Amelia Brand. Also, you will leave the Earth without children.""")
                    while True:
                        try:
                            time.sleep(2) #time delay during 2 seconds
                            # Repetitive (containing the same question inside) question
                            dlg_3 = input(prompt = """\n>> Do you agree, refuse, or do you need more information? 
Remember, you cannot come back here again. > """)

                            # Positive answer, leading to the next scene
                            if 'agree' in dlg_3.lower() or 'ye' in dlg_3.lower() or 'sur' in dlg_3.lower():
                                before_leaving()  #scene at home before leaving
                                break

                            # Negative answer to the question, leading to the fail()
                            elif 'dis' in dlg_3.lower() or 'refuse' in dlg_3.lower() or 'no' in dlg_3.lower():
                                fail_exemplary_family_man()   #failing

                                break

                            # Asking for an additional information
                            elif 'info' in dlg_3.lower() or 'more' in dlg_3.lower():
                                print("""\n""" + '\033[1m' + "You find out the following information:\n" + '\033[0m' +
"""In our galaxy, in the solar system, a wormhole was found near Saturn 48 years ago, leading to 12 potential 
habitable places. And NASA sent the most daring astronauts there 10 years ago.""")
                                while True:
                                    try:
                                        time.sleep(2) #time delay during 2 seconds
                                        # Repetitive (containing the same question inside) question
                                        dlg_3 = input(prompt = """\n>> Do you agree, refuse, or do you need more information? 
Remember, you cannot come back here again. > """)

                                        # Positive answer, leading to the next scene
                                        if 'agree' in dlg_3.lower() or 'ye' in dlg_3.lower() or 'sur' in dlg_3.lower():
                                            before_leaving()  #scene at home before leaving
                                            break

                                        # Negative answer to the question, leading to the fail()
                                        elif 'dis' in dlg_3.lower() or 'refuse' in dlg_3.lower() or 'no' in dlg_3.lower():
                                            fail_exemplary_family_man()   #failing
                                            break

                                        # Asking for an additional information
                                        elif 'info' in dlg_3.lower() or 'more' in dlg_3.lower():
                                            print("""\n""" + '\033[1m' + "You find out the following information:\n" 
+ '\033[0m' + """Only primitive binary code can go through a wormhole, and it seems that one system appears 
to be viable. Dr. Amelia Brand adds that this is one system with three potential viable worlds. This seems 
like a good chance.""")
                                            while True:
                                                try:
                                                    time.sleep(2) #time delay during 2 seconds
                                                    # Repetitive (containing the same question inside) question
                                                    dlg_3 = input(prompt = """\n>> Do you agree, refuse, or do you need more information? 
Remember, you cannot come back here again. > """)

                                                    # Positive answer, leading to the next scene
                                                    if 'agree' in dlg_3.lower() or 'ye' in dlg_3.lower() or 'sur' in dlg_3.lower():
                                                        before_leaving()  #scene at home before leaving
                                                        break

                                                    # Negative answer to the question, leading to the fail()
                                                    elif 'dis' in dlg_3.lower() or 'refuse' in dlg_3.lower() or 'no' in dlg_3.lower():
                                                        fail_exemplary_family_man()   #failing
                                                        break

                                                    # Asking for an additional information
                                                    elif 'info' in dlg_3.lower() or 'more' in dlg_3.lower():
                                                        print("""\n""" 
+ '\033[1m' + "You find out the following information:\n" + '\033[0m' +
"""Dr. Amelia Brand, who is flying with you on the expedition, and Professor Brand have plans A and B.
Plan A: The professor realized that it was possible to curb gravity to create a space station where humanity 
could be relocated. But the problem has not been solved... The professor promises you to complete it until 
the moment you arrive back.
Plan B: Place a population bomb on another planet with 5,000 fertilized eggs, which, through incubator 
reproduction, will create a colony of one hundred thousand people within 30 years.""")
                                                        while True:
                                                            try:
                                                                time.sleep(2) #time delay during 2 seconds
                                                                # The last question in a row
                                                                dlg_3 = input(prompt = """\n>> Do you agree or refuse? 
This is your last chance to make a choice. Remember, you cannot come back here again. > """)

                                                                # Positive answer, leading to the next scene
                                                                if 'agree' in dlg_3.lower() or 'ye' in dlg_3.lower() or 'sur' in dlg_3.lower():
                                                                    before_leaving()  #scene at home before leaving
                                                                    break

                                                                # Negative answer to the question, leading to the fail()
                                                                elif 'dis' in dlg_3.lower() or 'refuse' in dlg_3.lower() or 'no' in dlg_3.lower():
                                                                    fail_exemplary_family_man()   #failing
                                                                    break

                                                                # For the incorrect input in the input line
                                                                else:
                                                                    print("""\n> Perhaps you entered something wrong. 
Try to write""" + '\033[1m' + "'agree'" + '\033[0m' + """if you agree to become a captain and fly into space; """ +
'\033[1m' + "'refuse'" + '\033[0m' + """if you are not ready to leave Earth 
for this expedition (you cannot return here again).""")

                                                            except:   #for checking bugs
                                                                print("""005. Invalid entry. Something went wrong.""")
                                                        break

                                                    # For the incorrect input in the input line
                                                    else:
                                                        print("""\n> Perhaps you entered something wrong. 
Try to write""" + '\033[1m' + "'agree'" + '\033[0m' + """if you agree to become a captain and fly into space; """ +
'\033[1m' + "'refuse'" + '\033[0m' + """if you are not ready to leave Earth 
for this expedition (you cannot return here again);""" + '\033[1m' + "'info'" + '\033[0m' + 
"""if you need more information to make a selection.""")

                                                except:   #for checking bugs
                                                    print("""004. Invalid entry. Something went wrong.""")
                                            break

                                        # For the incorrect input in the input line
                                        else:
                                            print("""\n> Perhaps you entered something wrong. 
Try to write""" + '\033[1m' + "'agree'" + '\033[0m' + """if you agree to become a captain and fly into space; """ +
'\033[1m' + "'refuse'" + '\033[0m' + """if you are not ready to leave Earth 
for this expedition (you cannot return here again);""" + '\033[1m' + "'info'" + '\033[0m' + 
"""if you need more information to make a selection.""")

                                    except:   #for checking bugs
                                        print("""003. Invalid entry. Something went wrong.""")
                                break

                            # For the incorrect input in the input line
                            else:
                                print("""\n> Perhaps you entered something wrong. 
Try to write""" + '\033[1m' + "'agree'" + '\033[0m' + """if you agree to become a captain and fly into space; """ +
'\033[1m' + "'refuse'" + '\033[0m' + """if you are not ready to leave Earth 
for this expedition (you cannot return here again);""" + '\033[1m' + "'info'" + '\033[0m' + 
"""if you need more information to make a selection.""")

                        except:   #for checking bugs
                            print("""002. Invalid entry. Something went wrong.""")
                    break

                # For the incorrect input in the input line
                else:
                    print("""\n> Perhaps you entered something wrong. 
Try to write""" + '\033[1m' + "'agree'" + '\033[0m' + """if you agree to become a captain and fly into space; """ +
'\033[1m' + "'refuse'" + '\033[0m' + """if you are not ready to leave Earth 
for this expedition (you cannot return here again);""" + '\033[1m' + "'info'" + '\033[0m' + 
"""if you need more information to make a selection.""")

            except:   #for checking bugs
                print("""001. Invalid entry. Something went wrong.""")

Stage_1()
